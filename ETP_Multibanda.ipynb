# %%
import geemap
import os
import ee

# %%
Map = geemap.Map()
AOI = ee.FeatureCollection('users/Guillermo-Ortega/Limites/comunNic_6487')\
        .filter(ee.Filter.eq('Municipio', 'Granada'))
Map.add_basemap('HYBRID')
roi = ee.FeatureCollection('users/Guillermo-Ortega/MAG_Datos/parcela_muestral_Roger')
MODIS = ee.ImageCollection('MODIS/006/MOD16A2')

##################################### 2 0 0 1 #####################################################

MODIS_ene_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_01').int()

MODIS_feb_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_02').int()

MODIS_mar_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_03').int()

MODIS_abr_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_04').int()

MODIS_may_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_05').int()

MODIS_jun_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_06').int()

MODIS_jul_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_07').int()

MODIS_ago_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_08').int()

MODIS_sep_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_09').int()

MODIS_oct_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_10').int()

MODIS_nov_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_11').int()

MODIS_dic_2001 = MODIS.filter(ee.Filter.calendarRange(2001, 2001, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2001_12').int()

##################################### 2 0 0 2 #####################################################

MODIS_ene_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_01').int()

MODIS_feb_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_02').int()

MODIS_mar_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_03').int()

MODIS_abr_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_04').int()

MODIS_may_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_05').int()

MODIS_jun_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_06').int()

MODIS_jul_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_07').int()

MODIS_ago_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_08').int()

MODIS_sep_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_09').int()

MODIS_oct_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_10').int()

MODIS_nov_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_11').int()

MODIS_dic_2002 = MODIS.filter(ee.Filter.calendarRange(2002, 2002, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2002_12').int()

##################################### 2 0 0 3 #####################################################

MODIS_ene_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_01').int()

MODIS_feb_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_02').int()

MODIS_mar_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_03').int()

MODIS_abr_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_04').int()

MODIS_may_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_05').int()

MODIS_jun_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_06').int()

MODIS_jul_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_07').int()

MODIS_ago_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_08').int()

MODIS_sep_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_09').int()

MODIS_oct_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_10').int()

MODIS_nov_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_11').int()

MODIS_dic_2003 = MODIS.filter(ee.Filter.calendarRange(2003, 2003, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2003_12').int()

##################################### 2 0 0 4 #####################################################

MODIS_ene_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_01').int()

MODIS_feb_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_02').int()

MODIS_mar_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_03').int()

MODIS_abr_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_04').int()

MODIS_may_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_05').int()

MODIS_jun_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_06').int()

MODIS_jul_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_07').int()

MODIS_ago_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_08').int()

MODIS_sep_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_09').int()

MODIS_oct_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_10').int()

MODIS_nov_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_11').int()

MODIS_dic_2004 = MODIS.filter(ee.Filter.calendarRange(2004, 2004, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2004_12').int()


##################################### 2 0 0 5 #####################################################

MODIS_ene_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_01').int()

MODIS_feb_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_02').int()

MODIS_mar_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_03').int()

MODIS_abr_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_04').int()

MODIS_may_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_05').int()

MODIS_jun_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_06').int()

MODIS_jul_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_07').int()

MODIS_ago_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_08').int()

MODIS_sep_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_09').int()

MODIS_oct_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_10').int()

MODIS_nov_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_11').int()

MODIS_dic_2005 = MODIS.filter(ee.Filter.calendarRange(2005, 2005, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2005_12').int()

##################################### 2 0 0 6 #####################################################

MODIS_ene_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_01').int()

MODIS_feb_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_02').int()

MODIS_mar_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_03').int()

MODIS_abr_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_04').int()

MODIS_may_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_05').int()

MODIS_jun_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_06').int()

MODIS_jul_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_07').int()

MODIS_ago_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_08').int()

MODIS_sep_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_09').int()

MODIS_oct_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_10').int()

MODIS_nov_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_11').int()

MODIS_dic_2006 = MODIS.filter(ee.Filter.calendarRange(2006, 2006, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2006_12').int()

##################################### 2 0 0 7 #####################################################

MODIS_ene_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_01').int()

MODIS_feb_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_02').int()

MODIS_mar_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_03').int()

MODIS_abr_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_04').int()

MODIS_may_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_05').int()

MODIS_jun_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_06').int()

MODIS_jul_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_07').int()

MODIS_ago_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_08').int()

MODIS_sep_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_09').int()

MODIS_oct_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_10').int()

MODIS_nov_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_11').int()

MODIS_dic_2007 = MODIS.filter(ee.Filter.calendarRange(2007, 2007, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2007_12').int()

##################################### 2 0 0 8 #####################################################

MODIS_ene_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_01').int()

MODIS_feb_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_02').int()

MODIS_mar_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_03').int()

MODIS_abr_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_04').int()

MODIS_may_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_05').int()

MODIS_jun_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_06').int()

MODIS_jul_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_07').int()

MODIS_ago_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_08').int()

MODIS_sep_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_09').int()

MODIS_oct_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_10').int()

MODIS_nov_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_11').int()

MODIS_dic_2008 = MODIS.filter(ee.Filter.calendarRange(2008, 2008, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2008_12').int()

##################################### 2 0 0 9 #####################################################

MODIS_ene_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_01').int()

MODIS_feb_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_02').int()

MODIS_mar_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_03').int()

MODIS_abr_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_04').int()

MODIS_may_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_05').int()

MODIS_jun_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_06').int()

MODIS_jul_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_07').int()

MODIS_ago_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_08').int()

MODIS_sep_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_09').int()

MODIS_oct_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_10').int()

MODIS_nov_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_11').int()

MODIS_dic_2009 = MODIS.filter(ee.Filter.calendarRange(2009, 2009, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2009_12').int()

##################################### 2 0 1 0 #####################################################

MODIS_ene_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_01').int()

MODIS_feb_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_02').int()

MODIS_mar_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_03').int()

MODIS_abr_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_04').int()

MODIS_may_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_05').int()

MODIS_jun_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_06').int()

MODIS_jul_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_07').int()

MODIS_ago_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_08').int()

MODIS_sep_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_09').int()

MODIS_oct_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_10').int()

MODIS_nov_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_11').int()

MODIS_dic_2010 = MODIS.filter(ee.Filter.calendarRange(2010, 2010, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2010_12').int()

##################################### 2 0 1 1 #####################################################

MODIS_ene_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_01').int()

MODIS_feb_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_02').int()

MODIS_mar_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_03').int()

MODIS_abr_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_04').int()

MODIS_may_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_05').int()

MODIS_jun_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_06').int()

MODIS_jul_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_07').int()

MODIS_ago_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_08').int()

MODIS_sep_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_09').int()

MODIS_oct_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_10').int()

MODIS_nov_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_11').int()

MODIS_dic_2011 = MODIS.filter(ee.Filter.calendarRange(2011, 2011, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2011_12').int()

##################################### 2 0 1 2 #####################################################

MODIS_ene_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_01').int()

MODIS_feb_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_02').int()

MODIS_mar_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_03').int()

MODIS_abr_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_04').int()

MODIS_may_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_05').int()

MODIS_jun_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_06').int()

MODIS_jul_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_07').int()

MODIS_ago_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_08').int()

MODIS_sep_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_09').int()

MODIS_oct_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_10').int()

MODIS_nov_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_11').int()

MODIS_dic_2012 = MODIS.filter(ee.Filter.calendarRange(2012, 2012, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2012_12').int()

##################################### 2 0 1 3 #####################################################

MODIS_ene_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_01').int()

MODIS_feb_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_02').int()

MODIS_mar_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_03').int()

MODIS_abr_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_04').int()

MODIS_may_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_05').int()

MODIS_jun_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_06').int()

MODIS_jul_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_07').int()

MODIS_ago_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_08').int()

MODIS_sep_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_09').int()

MODIS_oct_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_10').int()

MODIS_nov_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_11').int()

MODIS_dic_2013 = MODIS.filter(ee.Filter.calendarRange(2013, 2013, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2013_12').int()

##################################### 2 0 1 4 #####################################################

MODIS_ene_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_01').int()

MODIS_feb_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_02').int()

MODIS_mar_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_03').int()

MODIS_abr_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_04').int()

MODIS_may_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_05').int()

MODIS_jun_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_06').int()

MODIS_jul_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_07').int()

MODIS_ago_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_08').int()

MODIS_sep_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_09').int()

MODIS_oct_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_10').int()

MODIS_nov_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_11').int()

MODIS_dic_2014 = MODIS.filter(ee.Filter.calendarRange(2014, 2014, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2014_12').int()


##################################### 2 0 1 5 #####################################################

MODIS_ene_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_01').int()

MODIS_feb_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_02').int()

MODIS_mar_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_03').int()

MODIS_abr_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_04').int()

MODIS_may_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_05').int()

MODIS_jun_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_06').int()

MODIS_jul_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_07').int()

MODIS_ago_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_08').int()

MODIS_sep_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_09').int()

MODIS_oct_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_10').int()

MODIS_nov_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_11').int()

MODIS_dic_2015 = MODIS.filter(ee.Filter.calendarRange(2015, 2015, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2015_12').int()

##################################### 2 0 1 6 #####################################################

MODIS_ene_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_01').int()

MODIS_feb_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_02').int()

MODIS_mar_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_03').int()

MODIS_abr_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_04').int()

MODIS_may_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_05').int()

MODIS_jun_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_06').int()

MODIS_jul_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_07').int()

MODIS_ago_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_08').int()

MODIS_sep_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_09').int()

MODIS_oct_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_10').int()

MODIS_nov_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_11').int()

MODIS_dic_2016 = MODIS.filter(ee.Filter.calendarRange(2016, 2016, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2016_12').int()

##################################### 2 0 1 7 #####################################################

MODIS_ene_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_01').int()

MODIS_feb_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_02').int()

MODIS_mar_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_03').int()

MODIS_abr_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_04').int()

MODIS_may_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_05').int()

MODIS_jun_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_06').int()

MODIS_jul_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_07').int()

MODIS_ago_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_08').int()

MODIS_sep_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_09').int()

MODIS_oct_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_10').int()

MODIS_nov_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_11').int()

MODIS_dic_2017 = MODIS.filter(ee.Filter.calendarRange(2017, 2017, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2017_12').int()

##################################### 2 0 1 8 #####################################################

MODIS_ene_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_01').int()

MODIS_feb_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_02').int()

MODIS_mar_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_03').int()

MODIS_abr_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_04').int()

MODIS_may_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_05').int()

MODIS_jun_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_06').int()

MODIS_jul_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_07').int()

MODIS_ago_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_08').int()

MODIS_sep_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_09').int()

MODIS_oct_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_10').int()

MODIS_nov_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_11').int()

MODIS_dic_2018 = MODIS.filter(ee.Filter.calendarRange(2018, 2018, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2018_12').int()

##################################### 2 0 1 9 #####################################################

MODIS_ene_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_01').int()

MODIS_feb_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_02').int()

MODIS_mar_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_03').int()

MODIS_abr_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_04').int()

MODIS_may_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_05').int()

MODIS_jun_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_06').int()

MODIS_jul_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_07').int()

MODIS_ago_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_08').int()

MODIS_sep_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_09').int()

MODIS_oct_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_10').int()

MODIS_nov_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_11').int()

MODIS_dic_2019 = MODIS.filter(ee.Filter.calendarRange(2019, 2019, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2019_12').int()

##################################### 2 0 2 0 #####################################################

MODIS_ene_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_01').int()

MODIS_feb_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_02').int()

MODIS_mar_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_03').int()

MODIS_abr_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_04').int()

MODIS_may_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_05').int()

MODIS_jun_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_06').int()

MODIS_jul_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_07').int()

MODIS_ago_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_08').int()

MODIS_sep_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_09').int()

MODIS_oct_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_10').int()

MODIS_nov_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_11').int()

MODIS_dic_2020 = MODIS.filter(ee.Filter.calendarRange(2020, 2020, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2020_12').int()

##################################### 2 0 2 1 #####################################################

MODIS_ene_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_01').int()

MODIS_feb_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_02').int()

MODIS_mar_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_03').int()

MODIS_abr_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_04').int()

MODIS_may_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_05').int()

MODIS_jun_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(6, 6, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_06').int()

MODIS_jul_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(7, 7, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_07').int()

MODIS_ago_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(8, 8, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_08').int()

MODIS_sep_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(9, 9, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_09').int()

MODIS_oct_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(10, 10, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_10').int()

MODIS_nov_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(11, 11, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_11').int()

MODIS_dic_2021 = MODIS.filter(ee.Filter.calendarRange(2021, 2021, 'year'))\
                      .filter(ee.Filter.calendarRange(12, 12, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2021_12').int()

##################################### 2 0 2 2 #####################################################

MODIS_ene_2022 = MODIS.filter(ee.Filter.calendarRange(2022, 2022, 'year'))\
                      .filter(ee.Filter.calendarRange(1, 1, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2022_01').int()

MODIS_feb_2022 = MODIS.filter(ee.Filter.calendarRange(2022, 2022, 'year'))\
                      .filter(ee.Filter.calendarRange(2, 2, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2022_02').int()

MODIS_mar_2022 = MODIS.filter(ee.Filter.calendarRange(2022, 2022, 'year'))\
                      .filter(ee.Filter.calendarRange(3, 3, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2022_03').int()

MODIS_abr_2022 = MODIS.filter(ee.Filter.calendarRange(2022, 2022, 'year'))\
                      .filter(ee.Filter.calendarRange(4, 4, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2022_04').int()

MODIS_may_2022 = MODIS.filter(ee.Filter.calendarRange(2022, 2022, 'year'))\
                      .filter(ee.Filter.calendarRange(5, 5, 'month'))\
                      .select('PET').mean().multiply(0.38).clip(AOI).rename('2022_05').int()

ETP_MODIS = MODIS_ene_2001.addBands(MODIS_feb_2001).addBands(MODIS_mar_2001).addBands(MODIS_abr_2001)\
.addBands(MODIS_may_2001).addBands(MODIS_jun_2001).addBands(MODIS_jul_2001).addBands(MODIS_ago_2001)\
.addBands(MODIS_sep_2001).addBands(MODIS_oct_2001).addBands(MODIS_nov_2001).addBands(MODIS_dic_2001)\
.addBands(MODIS_ene_2002).addBands(MODIS_feb_2002).addBands(MODIS_mar_2002).addBands(MODIS_abr_2002)\
.addBands(MODIS_may_2002).addBands(MODIS_jun_2002).addBands(MODIS_jul_2002).addBands(MODIS_ago_2002)\
.addBands(MODIS_sep_2002).addBands(MODIS_oct_2002).addBands(MODIS_nov_2002).addBands(MODIS_dic_2002)\
.addBands(MODIS_ene_2003).addBands(MODIS_feb_2003).addBands(MODIS_mar_2003).addBands(MODIS_abr_2003)\
.addBands(MODIS_may_2003).addBands(MODIS_jun_2003).addBands(MODIS_jul_2003).addBands(MODIS_ago_2003)\
.addBands(MODIS_sep_2003).addBands(MODIS_oct_2003).addBands(MODIS_nov_2003).addBands(MODIS_dic_2003)\
.addBands(MODIS_ene_2004).addBands(MODIS_feb_2004).addBands(MODIS_mar_2004).addBands(MODIS_abr_2004)\
.addBands(MODIS_may_2004).addBands(MODIS_jun_2004).addBands(MODIS_jul_2004).addBands(MODIS_ago_2004)\
.addBands(MODIS_sep_2004).addBands(MODIS_oct_2004).addBands(MODIS_nov_2004).addBands(MODIS_dic_2004)\
.addBands(MODIS_ene_2005).addBands(MODIS_feb_2005).addBands(MODIS_mar_2005).addBands(MODIS_abr_2005)\
.addBands(MODIS_may_2005).addBands(MODIS_jun_2005).addBands(MODIS_jul_2005).addBands(MODIS_ago_2005)\
.addBands(MODIS_sep_2005).addBands(MODIS_oct_2005).addBands(MODIS_nov_2005).addBands(MODIS_dic_2005)\
.addBands(MODIS_ene_2006).addBands(MODIS_feb_2006).addBands(MODIS_mar_2006).addBands(MODIS_abr_2006)\
.addBands(MODIS_may_2006).addBands(MODIS_jun_2006).addBands(MODIS_jul_2006).addBands(MODIS_ago_2006)\
.addBands(MODIS_sep_2006).addBands(MODIS_oct_2006).addBands(MODIS_nov_2006).addBands(MODIS_dic_2006)\
.addBands(MODIS_ene_2007).addBands(MODIS_feb_2007).addBands(MODIS_mar_2007).addBands(MODIS_abr_2007)\
.addBands(MODIS_may_2007).addBands(MODIS_jun_2007).addBands(MODIS_jul_2007).addBands(MODIS_ago_2007)\
.addBands(MODIS_sep_2007).addBands(MODIS_oct_2007).addBands(MODIS_nov_2007).addBands(MODIS_dic_2007)\
.addBands(MODIS_ene_2008).addBands(MODIS_feb_2008).addBands(MODIS_mar_2008).addBands(MODIS_abr_2008)\
.addBands(MODIS_may_2008).addBands(MODIS_jun_2008).addBands(MODIS_jul_2008).addBands(MODIS_ago_2008)\
.addBands(MODIS_sep_2008).addBands(MODIS_oct_2008).addBands(MODIS_nov_2008).addBands(MODIS_dic_2008)\
.addBands(MODIS_ene_2009).addBands(MODIS_feb_2009).addBands(MODIS_mar_2009).addBands(MODIS_abr_2009)\
.addBands(MODIS_may_2009).addBands(MODIS_jun_2009).addBands(MODIS_jul_2009).addBands(MODIS_ago_2009)\
.addBands(MODIS_sep_2009).addBands(MODIS_oct_2009).addBands(MODIS_nov_2009).addBands(MODIS_dic_2009)\
.addBands(MODIS_ene_2010).addBands(MODIS_feb_2010).addBands(MODIS_mar_2010).addBands(MODIS_abr_2010)\
.addBands(MODIS_may_2010).addBands(MODIS_jun_2010).addBands(MODIS_jul_2010).addBands(MODIS_ago_2010)\
.addBands(MODIS_sep_2010).addBands(MODIS_oct_2010).addBands(MODIS_nov_2010).addBands(MODIS_dic_2010)\
.addBands(MODIS_ene_2011).addBands(MODIS_feb_2011).addBands(MODIS_mar_2011).addBands(MODIS_abr_2011)\
.addBands(MODIS_may_2011).addBands(MODIS_jun_2011).addBands(MODIS_jul_2011).addBands(MODIS_ago_2011)\
.addBands(MODIS_sep_2011).addBands(MODIS_oct_2011).addBands(MODIS_nov_2011).addBands(MODIS_dic_2011)\
.addBands(MODIS_ene_2012).addBands(MODIS_feb_2012).addBands(MODIS_mar_2012).addBands(MODIS_abr_2012)\
.addBands(MODIS_may_2012).addBands(MODIS_jun_2012).addBands(MODIS_jul_2012).addBands(MODIS_ago_2012)\
.addBands(MODIS_sep_2012).addBands(MODIS_oct_2012).addBands(MODIS_nov_2012).addBands(MODIS_dic_2012)\
.addBands(MODIS_ene_2013).addBands(MODIS_feb_2013).addBands(MODIS_mar_2013).addBands(MODIS_abr_2013)\
.addBands(MODIS_may_2013).addBands(MODIS_jun_2013).addBands(MODIS_jul_2013).addBands(MODIS_ago_2013)\
.addBands(MODIS_sep_2013).addBands(MODIS_oct_2013).addBands(MODIS_nov_2013).addBands(MODIS_dic_2013)\
.addBands(MODIS_ene_2014).addBands(MODIS_feb_2014).addBands(MODIS_mar_2014).addBands(MODIS_abr_2014)\
.addBands(MODIS_may_2014).addBands(MODIS_jun_2014).addBands(MODIS_jul_2014).addBands(MODIS_ago_2014)\
.addBands(MODIS_sep_2014).addBands(MODIS_oct_2014).addBands(MODIS_nov_2014).addBands(MODIS_dic_2014)\
.addBands(MODIS_ene_2015).addBands(MODIS_feb_2015).addBands(MODIS_mar_2015).addBands(MODIS_abr_2015)\
.addBands(MODIS_may_2015).addBands(MODIS_jun_2015).addBands(MODIS_jul_2015).addBands(MODIS_ago_2015)\
.addBands(MODIS_sep_2015).addBands(MODIS_oct_2015).addBands(MODIS_nov_2015).addBands(MODIS_dic_2015)\
.addBands(MODIS_ene_2016).addBands(MODIS_feb_2016).addBands(MODIS_mar_2016).addBands(MODIS_abr_2016)\
.addBands(MODIS_may_2016).addBands(MODIS_jun_2016).addBands(MODIS_jul_2016).addBands(MODIS_ago_2016)\
.addBands(MODIS_sep_2016).addBands(MODIS_oct_2016).addBands(MODIS_nov_2016).addBands(MODIS_dic_2016)\
.addBands(MODIS_ene_2017).addBands(MODIS_feb_2017).addBands(MODIS_mar_2017).addBands(MODIS_abr_2017)\
.addBands(MODIS_may_2017).addBands(MODIS_jun_2017).addBands(MODIS_jul_2017).addBands(MODIS_ago_2017)\
.addBands(MODIS_sep_2017).addBands(MODIS_oct_2017).addBands(MODIS_nov_2017).addBands(MODIS_dic_2017)\
.addBands(MODIS_ene_2018).addBands(MODIS_feb_2018).addBands(MODIS_mar_2018).addBands(MODIS_abr_2018)\
.addBands(MODIS_may_2018).addBands(MODIS_jun_2018).addBands(MODIS_jul_2018).addBands(MODIS_ago_2018)\
.addBands(MODIS_sep_2018).addBands(MODIS_oct_2018).addBands(MODIS_nov_2018).addBands(MODIS_dic_2018)\
.addBands(MODIS_ene_2019).addBands(MODIS_feb_2019).addBands(MODIS_mar_2019).addBands(MODIS_abr_2019)\
.addBands(MODIS_may_2019).addBands(MODIS_jun_2019).addBands(MODIS_jul_2019).addBands(MODIS_ago_2019)\
.addBands(MODIS_sep_2019).addBands(MODIS_oct_2019).addBands(MODIS_nov_2019).addBands(MODIS_dic_2019)\
.addBands(MODIS_ene_2020).addBands(MODIS_feb_2020).addBands(MODIS_mar_2020).addBands(MODIS_abr_2020)\
.addBands(MODIS_may_2020).addBands(MODIS_jun_2020).addBands(MODIS_jul_2020).addBands(MODIS_ago_2020)\
.addBands(MODIS_sep_2020).addBands(MODIS_oct_2020).addBands(MODIS_nov_2020).addBands(MODIS_dic_2020)\
.addBands(MODIS_ene_2021).addBands(MODIS_feb_2021).addBands(MODIS_mar_2021).addBands(MODIS_abr_2021)\
.addBands(MODIS_may_2021).addBands(MODIS_jun_2021).addBands(MODIS_jul_2021).addBands(MODIS_ago_2021)\
.addBands(MODIS_sep_2021).addBands(MODIS_oct_2021).addBands(MODIS_nov_2021).addBands(MODIS_dic_2021)\
.addBands(MODIS_ene_2022).addBands(MODIS_feb_2022).addBands(MODIS_mar_2022).addBands(MODIS_abr_2022)\
.addBands(MODIS_may_2022).focalMean(1000, 'square', 'meters').int().clip(AOI)

# %%
vis_etp = {'bands': ['2022_03', '2022_04', '2022_05'], 'min': 150.0, 'max': 250.0}

Map.addLayer(ETP_MODIS, vis_etp, "etp (mm/mes) | 2001 - 2022", 1, 0.5)

Map.addLayer(AOI, {'color': 'ffffff', 'width': 0.1, 'lineType': 'solid', 'fillColor': 'ffffff00'},
             'Localidad', 1, 0.2)

Map.set_plot_options(plot_type ='bar', position='bottomright', max_width=800)
Map.centerObject(AOI)
Map

# %%
# m = geemap.Map().plot_demo()

# %%
# Map.set_plot_options(plot_type ='bar', add_marker_cluster = True)
